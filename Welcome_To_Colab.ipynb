# %% [markdown]
# <a href="https://colab.research.google.com/github/ibehchioma/My-journey-on-Machine-and-Deep-Learning/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## **HELPER FUNCTION**

# %%
#EXPLICIT INTERPHASE
def my_plotter(ax, data1, data2, param_dict):
    """
    A helper function to make a graph.
    """
    out = ax.plot(data1, data2, **param_dict)
    return out

# %%
data1, data2, data3, data4 = np.random.randn(4, 100)  # make 4 random data sets
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(5, 2.7))
my_plotter(ax1, data1, data2, {'marker': 'x'})
my_plotter(ax2, data3, data4, {'marker': 'o'})

# %%
#IMPLIICIT INTERPHASE
def my_plotter(data1, data2, param_dict):
    """
    A helper function to make a graph.
    """
    out = plt.plot(data1, data2, **param_dict)
    return out

# %%
data1, data2, data3, data4 = np.random.randn(4, 100)  # make 4 random data sets
plt.subplot(1, 2, 1)
my_plotter(data1, data2, {'marker': 'x'})
plt.subplot(1, 2, 2)
my_plotter(data3, data4, {'marker': 'o'})

# %% [markdown]
# STYLING ARTIST
